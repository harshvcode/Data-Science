# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df
#This model will predict whether a person will surive on the basis of Pclass, Sex, Age, Fare
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
inpu = df.drop(['Survived', 'PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis='columns')
inpu
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
targ = df['Survived']
targ
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_Pclass = LabelEncoder()
le_Sex = LabelEncoder()
le_Age = LabelEncoder()
le_Fare = LabelEncoder()

# %%
inpu['Pclass_n'] = le_Pclass.fit_transform(inpu['Pclass'])
inpu['Sex_n']= le_Pclass.fit_transform(inpu['Sex'])
inpu['Age_n']= le_Pclass.fit_transform(inpu['Age'])
inpu['Fare_n']= le_Pclass.fit_transform(inpu['Fare'])
inpu
# Out:
#      Pclass     Sex   Age     Fare  Pclass_n  Sex_n  Age_n  Fare_n
# 0         3    male  22.0   7.2500         2      1     28      18
# 1         1  female  38.0  71.2833         0      0     51     207
# 2         3  female  26.0   7.9250         2      0     34      41
# 3         1  female  35.0  53.1000         0      0     47     189
# 4         3    male  35.0   8.0500         2      1     47      43
# ..      ...     ...   ...      ...       ...    ...    ...     ...
# 886       2    male  27.0  13.0000         1      1     35      85
# 887       1  female  19.0  30.0000         0      0     24     153
# 888       3  female   NaN  23.4500         2      0     90     131
# 889       1    male  26.0  30.0000         0      1     34     153
# 890       3    male  32.0   7.7500         2      1     42      30
#
# [891 rows x 8 columns]

# %%
inpu_n = inpu.drop(['Pclass', 'Sex','Age', 'Fare'], axis = 'columns')
inpu_n
# Out:
#      Pclass_n  Sex_n  Age_n  Fare_n
# 0           2      1     28      18
# 1           0      0     51     207
# 2           2      0     34      41
# 3           0      0     47     189
# 4           2      1     47      43
# ..        ...    ...    ...     ...
# 886         1      1     35      85
# 887         0      0     24     153
# 888         2      0     90     131
# 889         0      1     34     153
# 890         2      1     42      30
#
# [891 rows x 4 columns]

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inpu_n, targ)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
inpu_n.head(10)
# Out:
#    Pclass_n  Sex_n  Age_n  Fare_n
# 0         2      1     28      18
# 1         0      0     51     207
# 2         2      0     34      41
# 3         0      0     47     189
# 4         2      1     47      43
# 5         2      1    110      51
# 6         0      1     69     186
# 7         2      1      6     124
# 8         2      0     35      74
# 9         1      0     18     154

# %%
model.predict([[2,1,28,186]])
#array([0]) means no survival, array([1]) means survival
# Out:
# array([0])

# %%
model.predict([[2,1,28,187]])
# Out:
# array([1])
